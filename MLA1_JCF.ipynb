# %% [markdown]
# <a href="https://colab.research.google.com/github/jcfarese/MLA_JCF/blob/main/MLA1_JCF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Machine Learning Assignment 1**
# ###**Jim Farese**
# ###**CS430**
# ###**Machine Learning in the Cloud**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##1. Read the file into a dataset named “df” from your Google Drive.

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MLA/weather_2012.csv')

# %% [markdown]
# ##2. Write the code to display the first five rows of the dataset, the last five rows of the dataset and a sample of five random rows from the dataset.

# %%
#The first 5 rows
df.head()
# Out:
#              Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 0  2012-01-01 00:00:00      -1.8                -3.9           86
# 1  2012-01-01 01:00:00      -1.8                -3.7           87
# 2  2012-01-01 02:00:00      -1.8                -3.4           89
# 3  2012-01-01 03:00:00      -1.5                -3.2           88
# 4  2012-01-01 04:00:00      -1.5                -3.3           88
#
#    Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)               Weather
# 0                4              8.0           101.24                   Fog
# 1                4              8.0           101.24                   Fog
# 2                7              4.0           101.26  Freezing Drizzle,Fog
# 3                6              4.0           101.27  Freezing Drizzle,Fog
# 4                7              4.8           101.23                   Fog

# %%
#The last 5 rows
df.tail()
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 8779  2012-12-31 19:00:00       0.1                -2.7           81
# 8780  2012-12-31 20:00:00       0.2                -2.4           83
# 8781  2012-12-31 21:00:00      -0.5                -1.5           93
# 8782  2012-12-31 22:00:00      -0.2                -1.8           89
# 8783  2012-12-31 23:00:00       0.0                -2.1           86
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# 8779               30              9.7           100.13    Snow
# 8780               24              9.7           100.03    Snow
# 8781               28              4.8            99.95    Snow
# 8782               28              9.7            99.91    Snow
# 8783               30             11.3            99.89    Snow

# %%
#5 Random rows
df.sample(5)
# Out:
#                 Date/Time  Temp (C)  Dew Point Temp (C)  Rel Hum (%)  \
# 1004  2012-02-11 20:00:00     -14.4               -19.9           63
# 7940  2012-11-26 20:00:00      -4.6               -10.0           66
# 1295  2012-02-23 23:00:00      -1.0                -5.2           73
# 5986  2012-09-06 10:00:00      24.7                17.8           65
# 1337  2012-02-25 17:00:00      -3.2                -8.4           67
#
#       Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# 1004                9             25.0           100.73         Clear
# 7940               13             25.0           101.85         Clear
# 1295                7             25.0           100.31         Clear
# 5986                6             24.1           100.55  Mainly Clear
# 1337               24             25.0            99.59        Cloudy

# %% [markdown]
# ##3. Write the code to display a list of all of the columns in the dataset.

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp (C)', 'Dew Point Temp (C)', 'Rel Hum (%)',
#        'Wind Spd (km/h)', 'Visibility (km)', 'Stn Press (kPa)', 'Weather'],
#       dtype='object')

# %% [markdown]
# ##4. The column names are unwieldy for our purposes. Rename them according to this list {date_time, temp_c, dew_point, relative_humidity, wind_speed, visibility, pressure, and weather}.

# %%
df = df.rename(columns = {'Date/Time' : 'date_time',
                          'Temp (C)' : 'temp_c',
                          'Dew Point Temp (C)':'dew_point',
                          'Rel Hum (%)':'relative_humidity',
                          'Wind Spd (km/h)':'wind_speed',
                          'Visibility (km)':'visibility',
                          'Stn Press (kPa)':'pressure',
                          'Weather':'weather'})
df.columns
# Out:
# Index(['date_time', 'temp_c', 'dew_point', 'relative_humidity', 'wind_speed',
#        'visibility', 'pressure', 'weather'],
#       dtype='object')

# %% [markdown]
# ##5. Most of the data in the dataset are numerical, write the code to get some standard statistics for each column (e.g. count, mean, etc.)

# %%
df.describe()
# Out:
#             temp_c    dew_point  relative_humidity   wind_speed   visibility  \
# count  8784.000000  8784.000000        8784.000000  8784.000000  8784.000000
# mean      8.798144     2.555294          67.431694    14.945469    27.664447
# std      11.687883    10.883072          16.918881     8.688696    12.622688
# min     -23.300000   -28.500000          18.000000     0.000000     0.200000
# 25%       0.100000    -5.900000          56.000000     9.000000    24.100000
# 50%       9.300000     3.300000          68.000000    13.000000    25.000000
# 75%      18.800000    11.800000          81.000000    20.000000    25.000000
# max      33.000000    24.400000         100.000000    83.000000    48.300000
#
#           pressure
# count  8784.000000
# mean    101.051623
# std       0.844005
# min      97.520000
# 25%     100.560000
# 50%     101.070000
# 75%     101.590000
# max     103.650000

# %% [markdown]
# ##6. Write the code to add a column named temp_f to the dataset that contains the temperature from temp_c represented in Fahrenheit.

# %%
df['temp_f'] = df['temp_c']*(9/5)+32

#Verify that there is a column and it converts the temperature correctly
df[['temp_f', 'temp_c']].sample(5)
# Out:
#       temp_f  temp_c
# 4760   70.70    21.5
# 2811   39.92     4.4
# 3939   66.74    19.3
# 4378   74.12    23.4
# 3606   62.96    17.2

# %% [markdown]
# ##7. Write the code to rearrange the columns in the dataset so temp_f appears immediately before temp_c.

# %%
column_order = ['date_time', 'temp_f', 'temp_c',
                'dew_point', 'relative_humidity', 'wind_speed',
                'visibility', 'pressure', 'weather']
df = df[column_order]
df.columns
# Out:
# Index(['date_time', 'temp_f', 'temp_c', 'dew_point', 'relative_humidity',
#        'wind_speed', 'visibility', 'pressure', 'weather'],
#       dtype='object')

# %% [markdown]
# ##8. Write the code to display the data types of all the columns in the dataset.

# %%
df.dtypes
# Out:
# date_time             object
# temp_f               float64
# temp_c               float64
# dew_point            float64
# relative_humidity      int64
# wind_speed             int64
# visibility           float64
# pressure             float64
# weather               object
# dtype: object

# %% [markdown]
# ##9. The date_time column is not actually considered a date by Pandas.  Write the code to convert this column to a date/time column and to verify the conversion was successful.

# %%
df['date_time'] = pd.to_datetime(df['date_time'])
df['date_time'].dtype
df['date_time'].sample()
# Out:
# 7775   2012-11-19 23:00:00
# Name: date_time, dtype: datetime64[ns]

# %% [markdown]
# ##10. Write the code to get the average temperature (in F) for each month and write it into an object called monthly_avg. This object should be a Pandas Series which is similar to a Pandas Dataframe except it only has one column.

# %%
#Converts the month from a numerical value to its name
df['month'] = df['date_time'].dt.strftime('%B')

monthly_avg = df.groupby('month')['temp_f'].mean()
monthly_avg = monthly_avg.reindex(['January', 'February', 'March', 'April',
                                   'May', 'June', 'July', 'August',
                                   'September', 'October', 'November', 'December'])

monthly_avg
# Out:
# month
# January      18.731290
# February     24.395000
# March        37.618226
# April        44.616750
# May          61.227984
# June         68.241250
# July         73.022097
# August       72.102742
# September    61.672000
# October      51.718952
# November     33.676500
# December     26.048629
# Name: temp_f, dtype: float64

# %% [markdown]
# ##11. Write code to generate a scatterplot that compares the temperature against the relative humidity.  The size of your plot should be 20 x 10

# %%
plt.figure(figsize = (20,10))
plt.scatter(df['temp_f'], df['relative_humidity'])
plt.title('Temperature Vs. Relative Humidity')
plt.xlabel('Temperature (F)')
plt.ylabel('Relative Humidity (%)')
plt.show()

# %% [markdown]
# ##12. Write the code to generate a line chart that shows the average temperature per month. The size of your plot should 20 x 10

# %%
plt.figure(figsize = (20,10))
plt.plot(monthly_avg)
plt.title('Average Temperature per Month')
plt.xlabel('Month')
plt.ylabel('Average Temperature (F)')
plt.show()

# %% [markdown]
# ##13. Write the code to generate a box plot. The size of your plot should 20 x 10

# %%
plt.figure(figsize = (20,10))

#Removes the grid
df.boxplot(grid = False)

plt.show()
